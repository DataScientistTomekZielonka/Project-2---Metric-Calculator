# %% [markdown]
# # Problem :
# Current dataset prepared for benchmark filtering ('small_dataset.xlsx') is too small (1000 rows) to consider adding to benchmark filtering another criterion which is Fill Rate. Secondly, this dataset does not have the feature Fill Rate and adding it is not possible.
#
# # Solution :
# 1. Use a current small dataset as a source for creating a large dataset by applying a bootstrap sampling approach.
# 2. Generate Fill Rate by applying Monte Carlo simulation.

# %%
import pandas as pd
import numpy as np
import random

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# %%
#import os
#import sys

#os.chdir('C:/Projects/Metric Calculator')
#sys.path.append('C:/Projects')

# %%
from constants import (
    VOIVODSHIP_LIST,
    INDUSTRY_LIST,
    JOB_TYPE_LIST
)

# %%
#Importing the source dataset

input_df = pd.read_excel('Datasets/small_dataset.xlsx')
input_df.head(10)
# Out:
#             Voivodship       Industry  \
# 0          Małopolskie    Warehousing
# 1       Świętokrzyskie  Manufacturing
# 2   Zachodniopomorskie  Manufacturing
# 3  Warmińsko-Mazurskie         Others
# 4              Śląskie    Warehousing
# 5  Warmińsko-Mazurskie  Manufacturing
# 6          Małopolskie  Manufacturing
# 7            Podlaskie         Others
# 8         Dolnośląskie  Manufacturing
# 9              Łódzkie  Manufacturing
#
#                                             Job Type    Salary    Bonus  \
# 0                   Machine operators, fitters, etc.   5462.52   978.73
# 1  Specialists, e.g. turners, welders, electricia...  10197.17  1738.25
# 2      Production workers, production operator, etc.   7568.14   818.59
# 3              Warehousment, warehouse workers, etc.   8825.89  2502.22
# 4                    Packers, pickers, sorters, etc.   6782.31  1786.56
# 5  Forklift operators, internal logistics operato...  10622.78   120.89
# 6  Specialists, e.g. turners, welders, electricia...  12258.43  3473.15
# 7      Production workers, production operator, etc.   5136.13   742.91
# 8                    Packers, pickers, sorters, etc.   6188.93   606.54
# 9                   Machine operators, fitters, etc.   9337.03   944.49
#
#        Benefits Contract Length           Contract Type Brand Recognition  \
# 0   One benefit               2  Contract of employment              Weak
# 1  Two benefits              12        Mandate contract              Weak
# 2   One benefit              19  Contract of employment          Moderate
# 3  Two benefits              10           Contract work         Very weak
# 4  Two benefits               5  Contract of employment            Strong
# 5   One benefit              22        Mandate contract       Very strong
# 6  Two benefits              20  Contract of employment            Strong
# 7  Two benefits              16  Contract of employment            Strong
# 8  Two benefits               1  Contract of employment          Moderate
# 9  Two benefits              17  Contract of employment            Strong
#
#   Recruitment Difficulty             Shifts             Overtime  \
# 0                 Normal    Two 8hrs shifts          No overtime
# 1                   Easy     One 8hrs shift          No overtime
# 2                 Normal    Two 8hrs shifts          No overtime
# 3              Very easy   Two 12hrs shifts  Ocassional overtime
# 4         Very difficult  Three 8hrs shifts  Ocassional overtime
# 5              Difficult     One 8hrs shift     Regular overtime
# 6                 Normal  Three 8hrs shifts  Ocassional overtime
# 7         Very difficult   Two 12hrs shifts  Ocassional overtime
# 8                   Easy  Three 8hrs shifts  Ocassional overtime
# 9                 Normal   Two 12hrs shifts          No overtime
#
#   Employee Satisfaction
# 0           Rather high
# 1            Rather low
# 2           Rather high
# 3              Very low
# 4              Moderate
# 5              Very low
# 6              Very low
# 7           Rather high
# 8           Rather high
# 9              Moderate

# %%
#Eliminating space in a 'Job Type' column (this column is a filtering key)

input_df.rename(columns = {'Job Type' : 'Job_Type'}, inplace = True)
input_df.head(3)
# Out:
#            Voivodship       Industry  \
# 0         Małopolskie    Warehousing
# 1      Świętokrzyskie  Manufacturing
# 2  Zachodniopomorskie  Manufacturing
#
#                                             Job_Type    Salary    Bonus  \
# 0                   Machine operators, fitters, etc.   5462.52   978.73
# 1  Specialists, e.g. turners, welders, electricia...  10197.17  1738.25
# 2      Production workers, production operator, etc.   7568.14   818.59
#
#        Benefits Contract Length           Contract Type Brand Recognition  \
# 0   One benefit               2  Contract of employment              Weak
# 1  Two benefits              12        Mandate contract              Weak
# 2   One benefit              19  Contract of employment          Moderate
#
#   Recruitment Difficulty           Shifts     Overtime Employee Satisfaction
# 0                 Normal  Two 8hrs shifts  No overtime           Rather high
# 1                   Easy   One 8hrs shift  No overtime            Rather low
# 2                 Normal  Two 8hrs shifts  No overtime           Rather high

# %%
#Creating a large dataset using bootstrap sampling

n = 30000 #number of rows declared for bootstrap generation - keep in mind that some filters combination may not return any rows for bootstrap (and the loop will pass) 

#Creating an empty bootstrap dataframe
output_df = pd.DataFrame(columns = input_df.columns)

#Loop for populating the bootstrap dataframe
for i in range(0, n) :
    
    #Creating a filtering criterions for selecting rows from which a single bootstrap row will be generated
    filtering_list = []

    filtering_list.append(random.choice(VOIVODSHIP_LIST))
    filtering_list.append(random.choice(INDUSTRY_LIST))
    filtering_list.append(random.choice(JOB_TYPE_LIST))
    
    voivodship = filtering_list[0]
    industry = filtering_list[1]
    job_type = filtering_list[2]
    
    #Checking whether filtering criterions will return any rows
    if len(input_df.query('\
           Voivodship == @voivodship and \
           Industry == @industry and \
           Job_Type == @job_type \
           ')) > 0 :
        
        #Selecting rows for particular bootstrap sample row
        df_filter = input_df.query('\
                    Voivodship == @voivodship and \
                    Industry == @industry and \
                    Job_Type == @job_type \
                    ')
        
        #Creating a single row via bootstrap sampling
        new_row = {col: np.random.choice(df_filter[col]) for col in df_filter.columns}
        
        #Adding newly created record to the bootstrap dataframe
        output_df = output_df.append(new_row, ignore_index = True)

# %%
len(output_df) # --> 26420 rows will do (c. 90% of declared procedures generated a bootstrap row)
# Out:
# 26420

# %% [markdown]
# BELOW : It has been agreed with the business representative that particular job types are more likely to yield 'Fill Rate' from specific intervals, like those below. Those intervals (delivered by the business representative) will be used in Monte Carlo simulation (dictionary job_type_proba_intervals_narrow).
#
# CAVEAT : Applying these intervals in Monte Carlo simulation will only generate 'Fill Rate' from these ranges; whilst some of real cases would be outside of them. To fix that issue a second dictionary is created where all job types fall into [0, 1] interval (dictionary job_type_proba_intervals_wide). Every time a dictionary will be randomly choosen.

# %%
job_type_proba_intervals_narrow = {
    "Forklift operators, internal logistics operators, etc." : [0.60, 0.75],
    "Machine operators, fitters, etc." : [0.70, 0.85],
    "Packers, pickers, sorters, etc." : [0.75, 0.90],
    "Production workers, production operator, etc." : [0.75, 0.95],
    "Specialists, e.g. turners, welders, electricians etc." : [0.55, 0.70],
    "Warehousment, warehouse workers, etc." : [0.65, 0.80]
}

# %%
job_type_proba_intervals_wide = {
    "Forklift operators, internal logistics operators, etc." : [0, 1],
    "Machine operators, fitters, etc." : [0, 1],
    "Packers, pickers, sorters, etc." : [0, 1],
    "Production workers, production operator, etc." : [0, 1],
    "Specialists, e.g. turners, welders, electricians etc." : [0, 1],
    "Warehousment, warehouse workers, etc." : [0, 1]
}

# %%
#Adding an ampty Fill Rate column

output_df['Fill_Rate'] = ""
output_df.head(3)
# Out:
#            Voivodship       Industry  \
# 0           Lubelskie    Warehousing
# 1  Zachodniopomorskie  Manufacturing
# 2             Śląskie         Others
#
#                                             Job_Type    Salary    Bonus  \
# 0              Warehousment, warehouse workers, etc.   6635.57   432.67
# 1              Warehousment, warehouse workers, etc.   7010.34   164.83
# 2  Specialists, e.g. turners, welders, electricia...  10376.41  2357.67
#
#        Benefits Contract Length           Contract Type Brand Recognition  \
# 0   No benefits              18  Contract of employment            Strong
# 1   One benefit               1  Contract of employment              Weak
# 2  Two benefits              11  Contract of employment       Very strong
#
#   Recruitment Difficulty             Shifts             Overtime  \
# 0                   Easy  Three 8hrs shifts  Ocassional overtime
# 1         Very difficult     One 8hrs shift  Ocassional overtime
# 2                 Normal    Two 8hrs shifts  Ocassional overtime
#
#   Employee Satisfaction Fill_Rate
# 0             Very high
# 1           Rather high
# 2              Very low

# %%
#Populating Fill Rate column using Monte Carlo simulation

for i in range(len(output_df)) :
    
    for j in range(len(JOB_TYPE_LIST)) :
        
        if output_df['Job_Type'].loc[i] == JOB_TYPE_LIST[j] :
            
            dict_choice = random.choice(['narrow', 'wide'])
            
            if  dict_choice == 'narrow' :
                
                #Converting dictionary wit NARROW intervals to a list of tuples, each tuple containing (job_type, lower, upper)
                data = [(job_type, proba[0], proba[1]) for job_type, proba in job_type_proba_intervals_narrow.items()]

                #Creating a DataFrame with probability bounds
                proba_df = pd.DataFrame(data, columns = ['Job_Type', 'Lower', 'Upper'])
            
            else :
            
                #Converting dictionary with WIDE to a list of tuples, each tuple containing (job_type, lower, upper)
                data = [(job_type, proba[0], proba[1]) for job_type, proba in job_type_proba_intervals_wide.items()]

                #Creating a DataFrame with probability bounds
                proba_df = pd.DataFrame(data, columns = ['Job_Type', 'Lower', 'Upper'])
            
            output_df['Fill_Rate'].loc[i] = random.uniform(proba_df['Lower'].loc[j], proba_df['Upper'].loc[j])

# %%
output_df.head(10)
# Out:
#            Voivodship       Industry  \
# 0           Lubelskie    Warehousing
# 1  Zachodniopomorskie  Manufacturing
# 2             Śląskie         Others
# 3  Zachodniopomorskie         Others
# 4             Śląskie    Warehousing
# 5         Mazowieckie  Manufacturing
# 6      Świętokrzyskie  Manufacturing
# 7  Zachodniopomorskie    Warehousing
# 8         Małopolskie         Others
# 9        Dolnośląskie    Warehousing
#
#                                             Job_Type    Salary    Bonus  \
# 0              Warehousment, warehouse workers, etc.   6635.57   432.67
# 1              Warehousment, warehouse workers, etc.   7010.34   164.83
# 2  Specialists, e.g. turners, welders, electricia...  10376.41  2357.67
# 3  Specialists, e.g. turners, welders, electricia...   5918.88  2026.99
# 4                   Machine operators, fitters, etc.   5615.66  1493.48
# 5                   Machine operators, fitters, etc.   8606.22  2566.72
# 6  Forklift operators, internal logistics operato...   2945.00   536.95
# 7              Warehousment, warehouse workers, etc.   6754.13   664.32
# 8                    Packers, pickers, sorters, etc.   5282.06   927.64
# 9                   Machine operators, fitters, etc.   8819.52   636.74
#
#        Benefits Contract Length           Contract Type Brand Recognition  \
# 0   No benefits              18  Contract of employment            Strong
# 1   One benefit               1  Contract of employment              Weak
# 2  Two benefits              11  Contract of employment       Very strong
# 3   One benefit               4           Contract work              Weak
# 4  Two benefits              14  Contract of employment       Very strong
# 5  Two benefits              19  Contract of employment       Very strong
# 6   One benefit              24  Contract of employment       Very strong
# 7  All benefits              13  Contract of employment            Strong
# 8  All benefits               3           Contract work       Very strong
# 9  Two benefits              23  Contract of employment            Strong
#
#   Recruitment Difficulty             Shifts             Overtime  \
# 0                   Easy  Three 8hrs shifts  Ocassional overtime
# 1         Very difficult     One 8hrs shift  Ocassional overtime
# 2                 Normal    Two 8hrs shifts  Ocassional overtime
# 3              Difficult     One 8hrs shift          No overtime
# 4                   Easy   Two 12hrs shifts  Ocassional overtime
# 5                   Easy   Two 12hrs shifts  Ocassional overtime
# 6              Difficult  Three 8hrs shifts          No overtime
# 7                 Normal   Two 12hrs shifts     Regular overtime
# 8                   Easy   Two 12hrs shifts     Regular overtime
# 9              Difficult  Three 8hrs shifts          No overtime
#
#   Employee Satisfaction Fill_Rate
# 0             Very high  0.794312
# 1           Rather high  0.695328
# 2              Very low  0.585503
# 3           Rather high   0.50554
# 4           Rather high  0.851513
# 5              Moderate   0.83467
# 6              Moderate  0.081316
# 7             Very high  0.765995
# 8           Rather high  0.214569
# 9              Moderate  0.404269

# %%
output_df.to_excel('Datasets/large_dataset.xlsx', index = False)
